# %% [markdown]
# In this method we are going to trverse the tree level by level, hence it is also called level order traversal. The data structure used to do BFS is a queue, since it will allow us to queue next level nodes while processing the current level nodes. The core strategy we follow is pop, process and add children. For example say we want to store level by level nodes in a array.
# ```
# def level_order(tree_node *root)
#    //result array to store the lists in
#    result = []
#
#    //define the queue and push the root
#    q = new queue();
#    q.push(root);
#
#    //Go level by level in a while loop
#    while(q not empty)
#    {
#      //get number of nodes at the current level
#      int size = q.size();
#
#      level_list = []
#      //loop all the nodes in the current level
#      for i = 1 to size
#      {
#        node = q.pop();
#
#        //HOW DO YOU WANT TO PROCESS THE CHILD
#        level_list.append(node.value);
#
#        //Add the child nodes of this node
#        if node.left:
#            q.push(node.left)
#        if node.right:
#            q.push(node.right)
#      }
#      // Once the for-loop ends:
#      // 1. All nodes at the current level are removed from the queue
#      // 2. All nodes at the next level are added in the queue
#      // 3. All nodes at the current level are collected in the `level` array
#
#      //WHAT DO YOU WANT TO DO ONCE A LEVEL IS COMPLETE
#      result.append(levelList)
#    }
#
#
#   //WHAT DO YOU WANT TO RETURN TO THE CLIENT
#   return result;
#
# ```
# Depending on the BFS problem, the parts in the above algorithm where comments are in all capital will change, otherwise the rest will remain same for all BFS problems. There is no need to touch the core strategy.

# %% [markdown]
# The time complexity of this algorithm is O(n) as we are using a while and for all and traversing all the nodes. Space complexity is equal to the max number of nodes in a level(pushing them to queue), for a complete binary tree, max number of nodes are n/2 at the leaf level, hence space complexity is O(n).
