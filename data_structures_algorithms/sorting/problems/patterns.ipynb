# %% [markdown]
# There are 2 well known patterns for solving problems on sorting, ordering and the related areas.
# * Two pointer technique : Use 2 pointers or indexes onto 2 different arrays or onto the same array depending on the problem, move the pointers as we solve the problem.
# * Sliding window technique : For problems where sub arrays are involved, we take a window for the sub array and move the window as per the problem to solve the problem.
